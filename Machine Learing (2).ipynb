# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from sklearn.preprocessing import StandardScaler 
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, roc_auc_score, precision_recall_curve, precision_score, accuracy_score
from sklearn.metrics import recall_score, classification_report, f1_score, roc_curve, auc

# %%
data=pd.read_csv('FinalData.csv')

# %%
Week_0_50=data.copy()

# %%
Week_0_50=Week_0_50.drop('Unnamed: 0',axis=1)

# %%
Week_0_50.head()
# Out:
#    CustomerId  Mean_1   Max_1   Min_1  Count_1  StandardDeviation_1  \
# 0        7260  171.20  171.20  171.20      1.0                  0.0
# 1       11024   68.48   68.48   68.48      1.0                  0.0
# 2       12476   51.36   51.36   51.36      1.0                  0.0
# 3       14156  171.20  171.20  171.20      1.0                  0.0
# 4       17606  171.20  171.20  171.20      1.0                  0.0
#
#    Revenue_1  Mean_2   Max_2   Min_2      ...       Count_4  \
# 0     171.20   128.4   85.60  171.20      ...           3.0
# 1      68.48    85.6   51.36  119.84      ...           1.0
# 2      51.36     0.0    0.00    0.00      ...           1.0
# 3     171.20   171.2  171.20  171.20      ...           1.0
# 4     171.20     0.0    0.00    0.00      ...           0.0
#
#    StandardDeviation_4  Revenue_4  Mean_5   Max_5   Min_5  Count_5  \
# 0            19.768473     445.12  145.52   68.48  171.20      4.0
# ...

# %%
Week_0_50['Week_2'] = Week_0_50['Revenue_2'] == 0

# %%
Week_0_50['Week_2'] = Week_0_50['Revenue_2'] == 0
Week_0_50['Week_3'] = Week_0_50['Revenue_3'] == 0
Week_0_50['Week_4'] = Week_0_50['Revenue_4'] == 0
Week_0_50['Week_5'] = Week_0_50['Revenue_5'] == 0

# %%
X = Week_0_50.drop(['Week_2','CustomerId'], axis=1)
Y = Week_0_50['Week_2']

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X, Y, test_size=0.3,random_state=0)
print(xtrain.shape, ytrain.shape)
print(xtest.shape, ytest.shape)
# Out:
# (134289, 31) (134289,)
# (57553, 31) (57553,)

# %%
clf_lr = LogisticRegression()

# %%
clf_lr.fit(xtrain, ytrain)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
lr_pred = clf_lr.predict(xtest)

# %%
xt = xtest.copy()
xt['pred'] = lr_pred
xt['actual'] = ytest
xt.head()
# Out:
#         Mean_1   Max_1   Min_1  Count_1  StandardDeviation_1  Revenue_1  \
# 142719    0.00    0.00    0.00      0.0             0.000000       0.00
# 41894    85.60   85.60   85.60      2.0             0.000000     171.20
# 139061    0.00    0.00    0.00      0.0             0.000000       0.00
# 37199   102.72  102.72  102.72      1.0             0.000000     102.72
# 53540   102.72   51.36  171.20      3.0            61.727038     308.16
#
#          Mean_2    Max_2    Min_2  Count_2   ...    Revenue_4  Mean_5  Max_5  \
# 142719     0.00     0.00     0.00      0.0   ...         0.00    0.00   0.00
# 41894     85.60    85.60    85.60      2.0   ...       205.44   85.60  85.60
# 139061  2568.00  2568.00  2568.00      1.0   ...         0.00    0.00   0.00
# 37199    102.72   102.72   102.72      1.0   ...       171.20    0.00   0.00
# 53540     77.04    51.36    85.60      4.0   ...       547.84  119.84  77.04
#
# ...

# %%
print(classification_report(ytest,lr_pred))
# Out:
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     33181
#        True       1.00      1.00      1.00     24372
#
# avg / total       1.00      1.00      1.00     57553

# %%
accuracy_score(ytest,lr_pred)
# Out:
# 0.9999652494222716

# %%
scaller=StandardScaler()
scaller.fit(xtrain)
S_X_train=scaller.transform(xtrain)
S_X_test=scaller.transform(xtest)

# %%
df_S_X_train=pd.DataFrame(S_X_train,columns=xtrain.columns)

# %%
df_S_X_test=pd.DataFrame(S_X_test,columns=xtest.columns)

# %%
KNN_Classification=KNeighborsClassifier(n_neighbors=5)

# %%
KNN_Classification.fit(S_X_train,ytrain)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
KNN_Prediction=KNN_Classification.predict(S_X_test)

# %%
test=xtest.copy()

# %%
test['Actual']=ytest

# %%
test['Predicted']=KNN_Prediction

# %%
print(classification_report(ytest,KNN_Prediction))
# Out:
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     33181
#        True       1.00      1.00      1.00     24372
#
# avg / total       1.00      1.00      1.00     57553

# %%
accuracy_score(ytest,lr_pred)
# Out:
# 0.9999652494222716

# %%
tree = DecisionTreeClassifier()
tree.fit(xtrain, ytrain)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
pred=tree.predict(xtest)

# %%
xt=xtest.copy()

# %%
xt['actual']=ytest
xt['pred']=pred

# %%
xt
# Out:
#             Mean_1   Max_1   Min_1  Count_1  StandardDeviation_1  Revenue_1  \
# 142719    0.000000    0.00    0.00      0.0             0.000000       0.00
# 41894    85.600000   85.60   85.60      2.0             0.000000     171.20
# 139061    0.000000    0.00    0.00      0.0             0.000000       0.00
# 37199   102.720000  102.72  102.72      1.0             0.000000     102.72
# 53540   102.720000   51.36  171.20      3.0            61.727038     308.16
# 38219    77.040000   77.04   77.04      1.0             0.000000      77.04
# 75751   171.200000  171.20  171.20      1.0             0.000000     171.20
# 67152    51.360000   51.36   51.36      1.0             0.000000      51.36
# 183186    0.000000    0.00    0.00      0.0             0.000000       0.00
# 109138    0.000000    0.00    0.00      0.0             0.000000       0.00
# 31323   239.680000  171.20  342.40      5.0            93.770102    1198.40
# ...

# %%
accuracy_score(ytest,pred)
# Out:
# 0.88989934762

# %%
print(classification_report(ytest,pred))
# Out:
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     33181
#        True       1.00      1.00      1.00     24372
#
# avg / total       1.00      1.00      1.00     57553

# %%
from sklearn.naive_bayes import GaussianNB

# %%
abc=GaussianNB()

# %%
abc.fit(xtrain,ytrain)
# Out:
# GaussianNB(priors=None)

# %%
Pred_n=abc.predict(xtest)

# %%
xtest['actual']=ytest
xtest['pred']=Pred_n
# Out:
# C:\Users\Abdul Haseeb\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Abdul Haseeb\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
print(classification_report(ytest,Pred_n))
# Out:
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00     33181
#        True       1.00      1.00      1.00     24372
#
# avg / total       1.00      1.00      1.00     57553

# %%
accuracy_score(ytest,pred)
# Out:
# 0.859247624331
